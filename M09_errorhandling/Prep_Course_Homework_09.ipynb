# %% [markdown]
# ## Manejo de errores

# %% [markdown]
# 1) Con la clase creada en el módulo 7, tener en cuenta diferentes casos en que el código pudiera arrojar error. Por ejemplo, en la creación del objeto recibimos una lista de números enteros pero ¿qué pasa si se envía otro tipo de dato?

# %%
class Numeros:
    '''Clase Numeros
    Funcion pública Ejecutar'''
    def __init__(self, numero_primo = None, lista_estadistica = None, lista_grados = None):
        # lista que guardará que funciones se ejecutarán
        self._orden_ejecucion = list()
        
        # Números Primos
        # elemento 0 de _orden_ejecucion
        if numero_primo is not None: 
            self._numero_primo = numero_primo
            self._orden_ejecucion.append(self._numero_primo)
        else:
            self._orden_ejecucion.append(None)
        
        # Estadísticas
        # elemento 1 de _orden_ejecucion
        if lista_estadistica is not None:
            self._lista_estadistica = lista_estadistica
            self._orden_ejecucion.append(self._lista_estadistica)
        else:
            self._orden_ejecucion.append(None)
        
        
        # Grados
        # elemento 2 de _orden_ejecucion
        if lista_grados is not None:
            self._lista_grados = lista_grados
            self._orden_ejecucion.append(self._lista_grados)
        else:
            self._orden_ejecucion.append(None)
            
        # comprobar que se cargue correctamente 
        # print(self._orden_ejecucion)
    
    def ejecutar(self):
        ''' Función ejecutar que llamará a todas las funciones
        según los datos pasados '''
        for indice, ejecucion in enumerate(self._orden_ejecucion):
            # verificar que funcione correctamente
            # print(indice, ejecucion)
            if indice == 0: #numero primo               
                if self._orden_ejecucion[indice] is not None:
                    print("Ingreso un dato en el lugar de primos")
                    return self._verificar(indice, self._numero_primo)
            elif indice == 1:
                # pregunta si ingreso una lista para verificar
                if self._orden_ejecucion[indice] is not None:
                    print("ingreso un dato para la estadistica")
                    return self._verificar(indice, self._lista_estadistica)
            elif indice == 2:
                # pregunta si ingreso una lista para verificar
                if self._orden_ejecucion[indice] is not None:
                    print("Ingreso un dato para la conversion de grados")
                    # verificar si hay una lista
                    return self._verificar(indice, self._lista_grados)
                    # verificar si el indice 0 es un numero (int o float)
                    # verificar si el indice 1 tiene dos elementos (origen y destino)
                    # realizar los calculos de conversion
            
        # return self._verificar()
        # pass
    
    def _verificar(self, indice, dato) -> (bool, list):
        # verificará los datos ingresados antes de 
        # correr cada funcion 
        if indice == 0: # NÚMERO PRIMO
            # verificar si es numero
            if self._comprobar_numero(dato):
                # si es numero... es positivo?
                if self._comprobar_positivo(dato):
                    # el numero es entero?
                    if self._comprobar_entero(dato):
                        return True, list(self._verificar_primo(dato))
            print("La verificacion de número primo falló")
            return False, -1
            # es_numero = self._comprobar_numero(dato)
            # return es_numero, dato
        elif indice == 1: #ESTADISTICA
            lista_rectificada = list()
            # verificar si hay una lista
            if self._comprobar_lista(dato):
                for elem in dato:
                    if self._comprobar_numero(elem):
                        lista_rectificada.append(elem)
                return True, list(self._calcular_estadistica(lista_rectificada))
                # return True, dato
            else:
                return False, dato
        elif indice == 2:
            # verificar si hay dos una listas
            # una lista para las temperaturas
            # una lista para las unidades a convertir
            # dato = [[temperatura],[unidades]]
            # comprobar si es una lista
            if self._comprobar_lista(dato):
                # comprobar si tiene dos elementos (temp y unid)
                if len(dato) == 2:
                    print("es lista con dos elementos")
                    if len(dato[0]) > 0:
                        print("Hay elementos que calcular")
                        if isinstance(dato[0][0],(int, float)):
                            print("Primera lista tiene elementos numericos")
                        else:
                            print("La primera lista de grados tiene que ser numerica")
                            if len(dato[0]) == 0:
                                print("Lista vacía: Agregue elementos")
                                return
                            elif len(dato[0]) < 2 or len(dato[0] > 2):
                                print("Verifique los datos cargados de ", dato[0])
                                return
                else:
                    print("no tiene dos elementos")
                    return 
                if not len(dato[1]) == 2:
                    print("Verifique que los datos cargados de ", dato[1], "tengas las unidades de origen y destino para la conversión.")
                    return
                else:
                    print("Verificacion de unidades: Tiene dos elementos")
            else:
                print("No es una lista")
                return
            
            resultado_grados = self._calcular_grados(dato[0], dato[1][0], dato[1][1])
            print("resultado: ",resultado_grados)
    
    def _comprobar_numero(self, dato) -> bool:
        # verificar si es booleano
        if isinstance(dato, bool):
            return False
        # verificar si el dato es un numero
        if isinstance(dato, (int, float)):
            return True
        return False
    
    def _comprobar_entero(self, dato) -> bool:
        if isinstance(dato, int):
            return True
        return False
    
    def _comprobar_decimal(self):
        pass 
    
    def _comprobar_lista(self, lista) -> bool:
        if isinstance(lista, list):
            return True
        return False  
    
    def _comprobar_positivo(self, dato) -> bool:
        if dato > 0:
            return True
        return False
    
    def _verificar_primo(self, numero) -> (bool, int):
        print("Verifico si es primo... :", numero)
        for n in range(2, numero):
            if numero % 2 == 0:
                print(f"No es primo, {n} es divisor de {numero}")
                return False, numero
        return True, numero
    
    def _calcular_estadistica(self, lista) -> (float, float, float):
        import statistics
        for elemento in lista:
            # comprobar si cada elemento es un numero
            if not self._comprobar_numero:
                print("La lista debe contener solo numeros!")
                return
        media = statistics.mean(lista)
        mediana = statistics.median(lista)
        moda = statistics.mode(lista)
        
        return media, mediana, moda
    
    def _calcular_grados(self, lista=None, origen=None, destino=None) -> float:
        # organizo las variables para la conversion
        if lista is None: return -1.0
        if origen is None: return -1.0
        if destino is None: return -1.0

        unidad_origen = origen[0].capitalize()
        unidad_destino = destino[0].capitalize()
        lista_temp_destino = list()
        
        for temp in lista:
            temp_origen = float(temp)
            if unidad_origen == "C" and unidad_destino == "K":
                lista_temp_destino.append(self._convertir_celsius_kelvin(temp_origen))
            elif unidad_origen == "K" and unidad_destino == "C":
                lista_temp_destino.append(self._convertir_kelvin_celsius(temp_origen))
            elif unidad_origen == "C" and unidad_destino == "F":
                lista_temp_destino.append(self._convertir_celsius_farenheit(temp_origen))
        return lista_temp_destino
        
        
    
    def _convertir_celsius_kelvin(self, temperatura):
        return temperatura + 273.15
    
    def _convertir_celsius_farenheit(self, temperatura):
        return temperatura * (9 / 5) + 32
    
    def _convertir_kelvin_celsius(self, temperatura):
        return temperatura - 273.15
    
    def _convertir_farenheit_kelvin(self):
        pass 
    
    def _convertir_farenheit_celsius(self):
        pass 
    
    def _convertir_kelvin_farenheit(self):
        pass 
    
    
# help(Numeros)
# primo = Numeros(lista_estadistica=1, lista_grados=[25.3,['Celsius','Kelvin']])
# print(primo.ejecutar())
# numeross = Numeros(lista_estadistica=1, lista_grados=[25.3,[]])
# funciones = Numeros(numero_primo=2.3)
# funciones = Numeros(numero_primo=6)
# funciones = Numeros(lista_estadistica=[1,2,2,2,5.3,8])
# funciones = Numeros(lista_estadistica=1)
funciones = Numeros(lista_grados=[[2.3,0,1,0,0,0],["Celsius","Kelvin"]])
print(funciones.ejecutar())
funciones = Numeros(lista_grados=[[2.3,0,1,0,0,0],["Celsius","Farehndlkasjf"]])
print(funciones.ejecutar())
funciones = Numeros(lista_grados=[[2.3,0,1,0,0,300],["kelvin", "Celsius"]])
print(funciones.ejecutar())
# Out:
# Ingreso un dato para la conversion de grados
# es lista con dos elementos
# Hay elementos que calcular
# Primera lista tiene elementos numericos
# Verificacion de unidades: Tiene dos elementos
# resultado:  [275.45, 273.15, 274.15, 273.15, 273.15, 273.15]
# None
# Ingreso un dato para la conversion de grados
# es lista con dos elementos
# Hay elementos que calcular
# Primera lista tiene elementos numericos
# Verificacion de unidades: Tiene dos elementos
# resultado:  [36.14, 32.0, 33.8, 32.0, 32.0, 32.0]
# None
# Ingreso un dato para la conversion de grados
# es lista con dos elementos
# Hay elementos que calcular
# Primera lista tiene elementos numericos
# Verificacion de unidades: Tiene dos elementos
# resultado:  [-270.84999999999997, -273.15, -272.15, -273.15, -273.15, 26.850000000000023]
# None

# %% [markdown]
# 2) En la función que hace la conversión de grados, validar que los parámetros enviados sean los esperados, de no serlo, informar cuáles son los valores esperados.

# %% [markdown]
# 3) Importar el modulo "unittest" y crear los siguientes casos de pruebas sobre la clase utilizada en el punto 2<br>
# Creacion del objeto incorrecta<br>
# Creacion correcta del objeto<br>
# Metodo valor_modal()<br>
#
# Se puede usar "raise ValueError()" en la creación de la clase para verificar el error. Investigar sobre esta funcionalidad.

# %% [markdown]
# 4) Probar una creación incorrecta y visualizar la salida del "raise"

# %% [markdown]
# 6) Agregar casos de pruebas para el método verifica_primos() realizando el cambio en la clase, para que devuelva una lista de True o False en función de que el elemento en la posisicón sea o no primo

# %% [markdown]
# 7) Agregar casos de pruebas para el método conversion_grados()

# %% [markdown]
# 8) Agregar casos de pruebas para el método factorial()
