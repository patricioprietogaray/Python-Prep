# %% [markdown]
# ## Flujos de Control

# %% [markdown]
# 1) Crear una variable que contenga un elemento del conjunto de números enteros y luego imprimir por pantalla si es mayor o menor a cero

# %%
numero = 23
if numero < 0:
    print("El numero", numero, "es menor a cero!")
elif numero > 0:
    print("El numero", numero, "es mayor a cero!")
else:
    print("El numero ", numero, "es igual a cero!")
# Out:
# El numero 23 es mayor a cero!

# %% [markdown]
# 2) Crear dos variables y un condicional que informe si son del mismo tipo de dato

# %%
var1=23.3
var2='sadlfkj'
if type(var1) == type(var2):
    print("Los tipos de las variables 1 y 2 son iguales")
else:
    print("Los tipos de las variables 1 y 2 NO son iguales")
# Out:
# Los tipos de las variables 1 y 2 NO son iguales

# %% [markdown]
# 3) Para los valores enteros del 1 al 20, imprimir por pantalla si es par o impar

# %%
for nume in range(1,21):
    if nume % 2 == 0:
        print("El numero", nume, "es par!")
    else:
        print("El numero", nume, "es impar!")
# Out:
# El numero 1 es impar!
# El numero 2 es par!
# El numero 3 es impar!
# El numero 4 es par!
# El numero 5 es impar!
# El numero 6 es par!
# El numero 7 es impar!
# El numero 8 es par!
# El numero 9 es impar!
# El numero 10 es par!
# El numero 11 es impar!
# El numero 12 es par!
# El numero 13 es impar!
# El numero 14 es par!
# El numero 15 es impar!
# El numero 16 es par!
# El numero 17 es impar!
# El numero 18 es par!
# El numero 19 es impar!
# El numero 20 es par!

# %% [markdown]
# 4) En un ciclo for mostrar para los valores entre 0 y 5 el resultado de elevarlo a la potencia igual a 3

# %%
for num in range(5):
    res = num ** 3
    print("el cubo de", num,"es:",res)
# Out:
# el cubo de 0 es: 0
# el cubo de 1 es: 1
# el cubo de 2 es: 8
# el cubo de 3 es: 27
# el cubo de 4 es: 64

# %% [markdown]
# 5) Crear una variable que contenga un número entero y realizar un ciclo for la misma cantidad de ciclos

# %%
repeticion=5
for i in range(repeticion):
    print("i:",i,"se repite hasta", repeticion, "veces")
# Out:
# i: 0 se repite hasta 5 veces
# i: 1 se repite hasta 5 veces
# i: 2 se repite hasta 5 veces
# i: 3 se repite hasta 5 veces
# i: 4 se repite hasta 5 veces

# %% [markdown]
# 6) Utilizar un ciclo while para realizar el factorial de un número guardado en una variable, sólo si la variable contiene un número entero mayor a 0

# %%
numero = 5
resultado = 0
while numero >= 2:
    if resultado == 0:
        resultado = numero
    numero -= 1
    resultado *= numero
print("El resutado final es:",resultado)
# Out:
# El resutado final es: 120

# %% [markdown]
# 7) Crear un ciclo for dentro de un ciclo while

# %%
numero_for=3
numero_while=0
while numero_while < 3:
    print(f"Numero While {numero_while}")
    for i in range(1,numero_for+1):
        print(f"Numero For {i}")        
    numero_while+=1
# Out:
# Numero While 0
# Numero For 1
# Numero For 2
# Numero For 3
# Numero While 1
# Numero For 1
# Numero For 2
# Numero For 3
# Numero While 2
# Numero For 1
# Numero For 2
# Numero For 3

# %% [markdown]
# 8) Crear un ciclo while dentro de un ciclo for

# %%
import random

for i in range(1,11):
    while True:
        resp = random.randint(1,100)
        if resp < 15:
            print(f"for: {i} y random menor al 15%")
            break
        else:
            print(i, "en random", resp)
# Out:
# 1 en random 75
# 1 en random 86
# 1 en random 40
# 1 en random 26
# 1 en random 47
# 1 en random 39
# 1 en random 16
# for: 1 y random menor al 15%
# 2 en random 42
# for: 2 y random menor al 15%
# 3 en random 30
# 3 en random 28
# 3 en random 41
# 3 en random 15
# for: 3 y random menor al 15%
# 4 en random 77
# 4 en random 31
# 4 en random 88
# 4 en random 90
# 4 en random 98
# for: 4 y random menor al 15%
# 5 en random 15
# 5 en random 31
# 5 en random 100
# 5 en random 45
# 5 en random 81
# 5 en random 86
# 5 en random 20
# for: 5 y random menor al 15%
# 6 en random 39
# 6 en random 99
# 6 en random 28
# 6 en random 91
# 6 en random 87
# 6 en random 17
# 6 en random 75
# 6 en random 71
# 6 en random 98
# 6 en random 78
# 6 en random 59
# 6 en random 43
# 6 en random 97
# for: 6 y random menor al 15%
# 7 en random 90
# 7 en random 99
# 7 en random 84
# 7 en random 91
# 7 en random 61
# 7 en random 72
# 7 en random 34
# 7 en random 76
# 7 en random 25
# 7 en random 73
# ...

# %% [markdown]
# 9) Imprimir los números primos existentes entre 0 y 30

# %%
primo=False
limite_evaluacion=30
print(f" +++ Numero Primo: 1")
print(f" +++ Numero Primo: 2")
print(f" +++ Numero Primo: 3")

for nro_a_evaluar in range(4,limite_evaluacion+1):
    print(f" ** Numero a evaluar: {nro_a_evaluar}")
    for rango_numeros in range(2,nro_a_evaluar):
        print(f"Rango de numeros: {rango_numeros}")
        if nro_a_evaluar % rango_numeros == 0:
            # print(f"division perfecta {rango_numeros}")
            primo=True
            break
    if nro_a_evaluar == rango_numeros + 1:
        print(f"El numero {nro_a_evaluar} es primo")
        print(f" +++ Numero Primo: {nro_a_evaluar}")
# Out:
#  +++ Numero Primo: 1
#  +++ Numero Primo: 2
#  +++ Numero Primo: 3
#  ** Numero a evaluar: 4
# Rango de numeros: 2
#  ** Numero a evaluar: 5
# Rango de numeros: 2
# Rango de numeros: 3
# Rango de numeros: 4
# El numero 5 es primo
#  +++ Numero Primo: 5
#  ** Numero a evaluar: 6
# Rango de numeros: 2
#  ** Numero a evaluar: 7
# Rango de numeros: 2
# Rango de numeros: 3
# Rango de numeros: 4
# Rango de numeros: 5
# Rango de numeros: 6
# El numero 7 es primo
#  +++ Numero Primo: 7
#  ** Numero a evaluar: 8
# Rango de numeros: 2
#  ** Numero a evaluar: 9
# Rango de numeros: 2
# Rango de numeros: 3
#  ** Numero a evaluar: 10
# Rango de numeros: 2
#  ** Numero a evaluar: 11
# Rango de numeros: 2
# Rango de numeros: 3
# Rango de numeros: 4
# Rango de numeros: 5
# Rango de numeros: 6
# Rango de numeros: 7
# Rango de numeros: 8
# Rango de numeros: 9
# Rango de numeros: 10
# El numero 11 es primo
#  +++ Numero Primo: 11
#  ** Numero a evaluar: 12
# Rango de numeros: 2
# ...

# %% [markdown]
# 10) ¿Se puede mejorar el proceso del punto 9? Utilizar las sentencias break y/ó continue para tal fin

# %%
# ya realizado pero se puede mejorar un poco la logica
limite_evaluacion = 30

# El 2 y el 3 son los primeros números primos
print(" +++ Numero Primo: 2")
print(" +++ Numero Primo: 3")

for nro_a_evaluar in range(4, limite_evaluacion + 1):
    es_primo = True  # Asumimos que es primo hasta demostrar lo contrario
    print(f"\n ** Numero a evaluar: {nro_a_evaluar}")
    
    for divisor in range(2, nro_a_evaluar):
        print(f"Probando divisor: {divisor}")
        
        if nro_a_evaluar % divisor == 0:
            es_primo = False  # Si se divide exactamente, NO es primo
            break  # Salimos del bucle de divisores
            
    # Evaluamos la bandera DESPUÉS de probar los divisores
    if es_primo:
        print(f" +++ Numero Primo: {nro_a_evaluar}")
# Out:
#  +++ Numero Primo: 2
#  +++ Numero Primo: 3
#
#  ** Numero a evaluar: 4
# Probando divisor: 2
#
#  ** Numero a evaluar: 5
# Probando divisor: 2
# Probando divisor: 3
# Probando divisor: 4
#  +++ Numero Primo: 5
#
#  ** Numero a evaluar: 6
# Probando divisor: 2
#
#  ** Numero a evaluar: 7
# Probando divisor: 2
# Probando divisor: 3
# Probando divisor: 4
# Probando divisor: 5
# Probando divisor: 6
#  +++ Numero Primo: 7
#
#  ** Numero a evaluar: 8
# Probando divisor: 2
#
#  ** Numero a evaluar: 9
# Probando divisor: 2
# Probando divisor: 3
#
#  ** Numero a evaluar: 10
# Probando divisor: 2
#
#  ** Numero a evaluar: 11
# Probando divisor: 2
# Probando divisor: 3
# Probando divisor: 4
# Probando divisor: 5
# Probando divisor: 6
# Probando divisor: 7
# Probando divisor: 8
# Probando divisor: 9
# Probando divisor: 10
#  +++ Numero Primo: 11
#
#  ** Numero a evaluar: 12
# Probando divisor: 2
#
#  ** Numero a evaluar: 13
# Probando divisor: 2
# Probando divisor: 3
# Probando divisor: 4
# ...

# %% [markdown]
# 11) En los puntos 9 y 10, se diseño un código que encuentra números primos y además se lo optimizó. ¿Es posible saber en qué medida se optimizó?

# %%
# acá optimizado mejor con for else sin while
limite_evaluacion = 30

print(" +++ Numero Primo: 2")
print(" +++ Numero Primo: 3")

for nro_a_evaluar in range(4, limite_evaluacion + 1):
    for divisor in range(2, nro_a_evaluar):
        if nro_a_evaluar % divisor == 0:
            break  # Encontró un divisor, no es primo
    else:
        # Se ejecuta SOLO si el bucle terminó sin hacer ningún break
        print(f" +++ Numero Primo: {nro_a_evaluar}")
# Out:
#  +++ Numero Primo: 2
#  +++ Numero Primo: 3
#  +++ Numero Primo: 5
#  +++ Numero Primo: 7
#  +++ Numero Primo: 11
#  +++ Numero Primo: 13
#  +++ Numero Primo: 17
#  +++ Numero Primo: 19
#  +++ Numero Primo: 23
#  +++ Numero Primo: 29

# %% [markdown]
# 12) Aplicando continue, armar un ciclo while que solo imprima los valores divisibles por 12, dentro del rango de números de 100 a 300

# %%
numero = 100
print("Imprimir solo los numeros divisibles por 12")
while numero < 301:
    if numero % 12 == 0:
        print(numero)
    numero = numero + 1
# Out:
# Imprimir solo los numeros divisibles por 12
# 108
# 120
# 132
# 144
# 156
# 168
# 180
# 192
# 204
# 216
# 228
# 240
# 252
# 264
# 276
# 288
# 300

# %% [markdown]
# 13) Utilizar la función **input()** que permite hacer ingresos por teclado, para encontrar números primos y dar la opción al usario de buscar el siguiente

# %%
# acá optimizado mejor con for else sin while
while True:
    primo=True
    verificar_numero = int(input("Ingrese un numero para verificar si es primo: "))
    if verificar_numero < 4:
        primo=True
    elif verificar_numero >= 4:
        for divisor in range(2, verificar_numero):
            # print(f"Verificar el numero {verificar_numero} dividido por {divisor}")
            if verificar_numero > divisor > 1:
                # print("dentro del rango de búsqueda")
                resto = verificar_numero % divisor
                if resto == 0:
                    # print("resto 0 y esta dentro del rango de busqueda, no es primo")
                    primo=False

    if primo == True:
        print(f"El numero {str(verificar_numero)} es primo")
    else:
        print(f"El numero {str(verificar_numero)} NO es primo")
        primo=True
# Out:
# El numero 17 es primo
# resto 0 y esta dentro del rango de busqueda, no es primo
# resto 0 y esta dentro del rango de busqueda, no es primo
# resto 0 y esta dentro del rango de busqueda, no es primo
# resto 0 y esta dentro del rango de busqueda, no es primo
# El numero 18 NO es primo

# %% [markdown]
# 14) Crear un ciclo while que encuentre dentro del rango de 100 a 300 el primer número divisible por 3 y además múltiplo de 6

# %%
# num=100

# while num <= 300:
#     divis_3=False
#     multi_6=False
#     if divis_3 == False: # si divis_3 es falso
#         if num % 3 == 0:
#             divis_3=True
#         if num % 2 == 0 and divis_3 == True: # si el numero es par 
#             multi_6 = True                   # y divi x 3 es multiplo de 6

#     if divis_3==True and multi_6==True:
#         print(f"El numero {num} es divisible por 3 y multiplo de 6")
#         break
#     num = num + 1

# más óptimo que el anterior
# num=100
# while num <= 300:
#     if num % 3 == 0 and num % 2 == 0:
#         print(f"El numero {num} es divisible por 3 y multiplo de 6")
#         break
#     num = num + 1
        
# aún más óptimo
num=100
while num <= 300:
    if num % 6 == 0:
        print(f"El numero {num} es divisible por 3 y multiplo de 6")
        break
    num = num + 1
# Out:
# El numero 102 es divisible por 3 y multiplo de 6
