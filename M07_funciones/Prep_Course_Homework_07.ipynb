# %% [markdown]
# ## Funciones

# %% [markdown]
# 1) Crear una función que reciba un número como parámetro y devuelva True si es primo y False si no lo es

# %%
print("Evaluando si el numero es primo")
print("Nota: Un numero primo es aquel que solo es divisible por 1 y por si mismo")
print("Nota: Los numeros primos son mayores a 1")
print("Nota: El numero 2 es el unico numero primo par")

numero_evaluar = 5 # 5 es primo
es_primo = True

# if numero_evaluar < 2:
#     es_primo = False
# elif numero_evaluar == 2:
#     es_primo = True
# else:
#     for divisor in range(2, numero_evaluar):
#         print(f"Evaluando si {numero_evaluar} es divisible por {divisor}")
# #         if numero_evaluar % divisor == 0:
# #             es_primo = False
# #             break




# # for nro_a_evaluar in range(4, limite_evaluacion + 1):
# #     for divisor in range(2, nro_a_evaluar):
# #         if nro_a_evaluar % divisor == 0:
# #             break  # Encontró un divisor, no es primo
# #     else:
# #         # Se ejecuta SOLO si el bucle terminó sin hacer ningún break
# #         print(f" +++ Numero Primo: {nro_a_evaluar}")
# Out:
# Evaluando si el numero es primo
# Nota: Un numero primo es aquel que solo es divisible por 1 y por si mismo
# Nota: Los numeros primos son mayores a 1
# Nota: El numero 2 es el unico numero primo par

# %% [markdown]
# 2) Utilizando la función del punto 1, realizar otra función que reciba de parámetro una lista de números y devuelva sólo aquellos que son primos en otra lista

# %% [markdown]
# 3) Crear una función que al recibir una lista de números, devuelva el que más se repite y cuántas veces lo hace. Si hay más de un "más repetido", que devuelva cualquiera

# %% [markdown]
# 4) Crear una función que convierta entre grados Celsius, Farenheit y Kelvin<br>
# Fórmula 1	: (°C × 9/5) + 32 = °F<br>
# Fórmula 2	: °C + 273.15 = °K<br>
# Debe recibir 3 parámetros: el valor, la medida de orígen y la medida de destino

# %% [markdown]
# 5) Iterando una lista con los tres valores posibles de temperatura que recibe la función del punto 5, hacer un print para cada combinación de los mismos:

# %% [markdown]
# 6) Armar una función que devuelva el factorial de un número. Tener en cuenta que el usuario puede equivocarse y enviar de parámetro un número no entero o negativo
