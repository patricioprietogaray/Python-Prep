# %%
# conversion de datos mediante 
# el proceso de casting
num=3.5
print(type(num))
print(num)
# Out:
# <class 'float'>
# 3.5

# %%
# convertir num que es float a entero int
num_int = int(num)
print(num_int)
print(type(num_int))
# Out:
# 3
# <class 'int'>

# %%
print(float(num_int))
# Out:
# 3.0

# %%
num_str="34"
res = num_str+"5"
nume = int(num_str)
res1 = nume + 5
print(res)
print(res1)
# Out:
# 345
# 39

# %%
num_fl=float(num_str)
num_fl
# Out:
# 34.0

# %%
# 1. Definimos el número inicial 1 (en 3 bits se ve como '001')
numero = 1
print("Inicio:             ", f"{numero:03b}")  # Muestra: 001

# 2. Desplazamos el bit 2 posiciones a la izquierda
binario_1 = numero << 2

# 3. Imprimimos el resultado formateado a 3 bits
print("Luego de mover << 2: ", f"{binario_1:03b}")  # Muestra: 100
print(int(binario_1))
# Out:
# Inicio:              001
# Luego de mover << 2:  100
# 4
